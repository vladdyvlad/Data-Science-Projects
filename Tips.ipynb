# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
import seaborn as sns

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.day.unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Sun', 'Sat', 'Thur', 'Fri']

# %%
tips.time.unique()
# Out:
# ['Dinner', 'Lunch']
# Categories (2, object): ['Dinner', 'Lunch']

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.time.value_counts()
# Out:
# Dinner    176
# Lunch      68
# Name: time, dtype: int64

# %%
tips.day.value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
# Not the correct type of chart
tips.time.value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
tips.time.value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
# The proportion of the dinner and lunches 
tips.time.value_counts(normalize = True)
# Out:
# Dinner    0.721311
# Lunch     0.278689
# Name: time, dtype: float64

# %%
# When do people tend to tip more
# This shows the avaerge of tips for each 
tips.groupby(['time'])['tip'].mean()
# Out:
# time
# Lunch     2.728088
# Dinner    3.102670
# Name: tip, dtype: float64

# %%
tips.groupby(['time'])['tip'].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
tips.groupby(['smoker','sex'])['tip'].mean()
# Out:
# smoker  sex
# Yes     Male      3.051167
#         Female    2.931515
# No      Male      3.113402
#         Female    2.773519
# Name: tip, dtype: float64

# %%
tips.groupby(['smoker','sex'])['tip'].mean().unstack()
# Out:
# sex         Male    Female
# smoker
# Yes     3.051167  2.931515
# No      3.113402  2.773519

# %%
tips['tip_per'] = tips.tip / tips.total_bill

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size   tip_per
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.166587
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.139780
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.146808

# %%
tips.plot.scatter(x = 'total_bill', y = 'tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
#seaborn plotting 
sns.scatterplot(x = 'total_bill', y = 'tip', data= tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
#seaborn plotting 
sns.scatterplot(x = 'total_bill', y = 'tip', data= tips, hue = 'sex')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
#seaborn plotting 
sns.scatterplot(x = 'total_bill', y = 'tip', data= tips, hue = 'time')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
#seaborn plotting 
sns.relplot(x = 'total_bill', y = 'tip', data= tips, col = "sex", 
                hue ='time' , )

# %%
sns.displot(data = tips, x = "total_bill", col = "time", kde = True)

# %%
# More people are coming in during dinner and paying more on average

# %%
sns.displot(data = tips, x = "tip", col = "time", kde = True)

# %%
sns.pairplot(data = tips, hue = 'sex')
